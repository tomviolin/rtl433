# %%
run graphit.py
# Out:
# eom chart20240608_165425.png

# %%
datenum
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 datenum
#
# NameError: name 'datenum' is not defined

# %%
datenums
# Out:
# array([1717557607, 1717558317, 1717558447, ..., 1717882961, 1717883320,
#        1717883451], dtype=uint64)
