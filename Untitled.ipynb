# %%
run graphit.py
# Out:
# eom chart20240608_165425.png

# %%
np.diff(datenums)
# Out:
# array([710, 130, 280, ...,  10, 359, 131], dtype=uint64)

# %%
datenums
# Out:
# array([1717557607, 1717558317, 1717558447, ..., 1717882961, 1717883320,
#        1717883451], dtype=uint64)

# %%
regdates = np.arange(datenums.min(),datenums.max(), 15*60)

# %%
regy = np.interp(regdates,datenums,pdf.Consumption)

# %%
plt.plot(datenums, regy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.plot(datenums, regy)
#
# File ~/rtl433/venv/lib/python3.10/site-packages/matplotlib/pyplot.py:2748, in plot(scalex, scaley, data, *args, **kwargs)
#    2746 @_copy_docstring_and_deprecators(Axes.plot)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2748     return gca().plot(
#    2749         *args, scalex=scalex, scaley=scaley,
#    2750         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/rtl433/venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1668, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1425 """
#    1426 Plot y versus x as lines and/or markers.
#    1427
#    (...)
#    1665 (``'green'``) or hex strings (``'#008000'``).
#    1666 """
#    1667 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
datenums.shape
# Out:
# (1459,)

# %%
pdf.Consumption.shape
# Out:
# (1459,)

# %%
np.interp?
# Out:
# Signature: np.interp(x, xp, fp, left=None, right=None, period=None)
# Docstring:
# One-dimensional linear interpolation for monotonically increasing sample points.
#
# Returns the one-dimensional piecewise linear interpolant to a function
# with given discrete data points (`xp`, `fp`), evaluated at `x`.
#
# Parameters
# ----------
# x : array_like
#     The x-coordinates at which to evaluate the interpolated values.
#
# xp : 1-D sequence of floats
#     The x-coordinates of the data points, must be increasing if argument
#     `period` is not specified. Otherwise, `xp` is internally sorted after
#     normalizing the periodic boundaries with ``xp = xp % period``.
#
# fp : 1-D sequence of float or complex
#     The y-coordinates of the data points, same length as `xp`.
#
# left : optional float or complex corresponding to fp
#     Value to return for `x < xp[0]`, default is `fp[0]`.
#
# right : optional float or complex corresponding to fp
# ...

# %%
regy = np.interp(regdates, datenums, pdf.Consumption)

# %%
regy
# Out:
# array([69929.        , 69929.        , 69929.        , 69929.        ,
#        69929.        , 69929.        , 69929.        , 69929.        ,
#        69929.        , 69929.        , 69929.        , 69929.        ,
#        69929.        , 69929.        , 69929.76849183, 69930.        ,
#        69930.        , 69930.        , 69930.        , 69930.        ,
#        69930.        , 69930.        , 69930.        , 69930.        ,
#        69930.        , 69930.        , 69931.        , 69931.        ,
#        69931.        , 69931.        , 69931.        , 69931.        ,
#        69931.        , 69931.        , 69931.        , 69931.        ,
#        69932.        , 69932.        , 69932.        , 69932.        ,
#        69932.        , 69932.        , 69932.        , 69932.        ,
#        69932.        , 69932.        , 69932.        , 69932.        ,
#        69932.        , 69932.        , 69932.        , 69932.        ,
# ...

# %%
regy.shape
# Out:
# (363,)

# %%
plt.plot(regdates,regy)

# %%
cdiff = np.diff(regy)

# %%
plt.plot(regdates[:-1],cdiff)

# %%
run graphit.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/rtl433/graphit.py:64
#      61 regdates = np.arange(datenums.min(),datenums.max(), 30*60)
#      62 regy = np.interp(regdates, datenums, pdf.Consumption)
# ---> 64 regdatedates = np.datetime64(regdates)
#      69 fig,ax = plt.subplots(2,figsize=(14,8))
#      70 fig.tight_layout()
#
# ValueError: Could not convert object to NumPy datetime

# %%
regdates.dtype
# Out:
# dtype('float64')

# %%
datenums.dtype
# Out:
# dtype('uint64')

# %%
np.datetime64(datenums,'us')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 np.datetime64(datenums,'us')
#
# ValueError: Could not convert object to NumPy datetime

# %% [markdown]
# datenums

# %%
datenums.astype(long)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 datenums.astype(long)
#
# NameError: name 'long' is not defined

# %%
datenums[0:10]
# Out:
# array([1717557607, 1717558317, 1717558447, 1717558727, 1717558947,
#        1717559197, 1717559727, 1717559817, 1717559997, 1717560817],
#       dtype=uint64)

# %%
np.uint64(np.datetime64(datetime.now(),'s'))
# Out:
# 1717867802

# %%
datenums[0]
# Out:
# 1717557607

# %%
np.datetime64(datenums[0],'s')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 np.datetime64(datenums[0],'s')
#
# ValueError: Could not convert object to NumPy datetime

# %%
datenums[0].dtype
# Out:
# dtype('uint64')

# %%
np.datetime64(np.int64(datenums[0]),'s')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 np.datetime64(np.int64(datenums[0]),'s')
#
# ValueError: Could not convert object to NumPy datetime

# %%
pd.to_datetime(datenums,unit='s',utc=True)
# Out:
# DatetimeIndex(['2024-06-05 03:20:07+00:00', '2024-06-05 03:31:57+00:00',
#                '2024-06-05 03:34:07+00:00', '2024-06-05 03:38:47+00:00',
#                '2024-06-05 03:42:27+00:00', '2024-06-05 03:46:37+00:00',
#                '2024-06-05 03:55:27+00:00', '2024-06-05 03:56:57+00:00',
#                '2024-06-05 03:59:57+00:00', '2024-06-05 04:13:37+00:00',
#                ...
#                '2024-06-08 21:40:50+00:00', '2024-06-08 21:42:31+00:00',
#                '2024-06-08 21:42:41+00:00', '2024-06-08 21:48:40+00:00',
#                '2024-06-08 21:50:51+00:00', '2024-06-08 21:54:30+00:00',
#                '2024-06-08 21:57:00+00:00', '2024-06-08 21:59:11+00:00',
#                '2024-06-08 22:05:20+00:00', '2024-06-08 22:15:51+00:00'],
#               dtype='datetime64[ns, UTC]', length=1464, freq=None)

# %%
pd.to_datetime?
# Out:
# Signature:
# pd.to_datetime(
#     arg: 'DatetimeScalarOrArrayConvertible | DictConvertible',
#     errors: 'DateTimeErrorChoices' = 'raise',
#     dayfirst: 'bool' = False,
#     yearfirst: 'bool' = False,
#     utc: 'bool | None' = None,
#     format: 'str | None' = None,
#     exact: 'bool' = True,
#     unit: 'str | None' = None,
#     infer_datetime_format: 'bool' = False,
#     origin='unix',
#     cache: 'bool' = True,
# ) -> 'DatetimeIndex | Series | DatetimeScalar | NaTType | None'
# Docstring:
# Convert argument to datetime.
#
# This function converts a scalar, array-like, :class:`Series` or
# :class:`DataFrame`/dict-like to a pandas datetime object.
#
# Parameters
# ----------
# arg : int, float, str, datetime, list, tuple, 1-d array, Series, DataFrame/dict-like
#     The object to convert to a datetime. If a :class:`DataFrame` is provided, the
#     method expects minimally the following columns: :const:`"year"`,
#     :const:`"month"`, :const:`"day"`.
# ...

# %%
dates[-1]
# Out:
# numpy.datetime64('2024-06-08T22:15:51')
