# %%
run graphit.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/rtl433/graphit.py:75
#      72 #dates=dates[1:]
#      73 n=0
# ---> 75 ax[n].plot(regdatedates[:-1],regy,'.-',label="Consumption rate")
#      76 ax[n].legend()
#      77 #ax[n].set_xlim(xlim)
#
# File ~/rtl433/venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1668, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1425 """
#    1426 Plot y versus x as lines and/or markers.
#    1427
#    (...)
#    1665 (``'green'``) or hex strings (``'#008000'``).
#    1666 """
#    1667 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1668 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1669 for line in lines:
#    1670     self.add_line(line)
#
# File ~/rtl433/venv/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
# ...

# %%
run graphit.py
# Out:
# eom chart20240608_183830.png

# %%
run graphit.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/rtl433/graphit.py:75
#      72 #dates=dates[1:]
#      73 n=0
# ---> 75 ax[n].plot(regdatedates[:-1],cons,'.-',label="Consumption rate")
#      76 ax[n].legend()
#      77 #ax[n].set_xlim(xlim)
#
# File ~/rtl433/venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1668, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1425 """
#    1426 Plot y versus x as lines and/or markers.
#    1427
#    (...)
#    1665 (``'green'``) or hex strings (``'#008000'``).
#    1666 """
#    1667 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1668 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1669 for line in lines:
#    1670     self.add_line(line)
#
# File ~/rtl433/venv/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
# ...

# %%
run graphit.py
# Out:
# eom chart20240608_181824.png

# %%
run graphit.py
# Out:
# eom chart20240608_182704.png

# %%
run graphit.py
# Out:
# eom chart20240608_183025.png

# %%
run graphit.py
# Out:
# eom chart20240608_183408.png

# %%
run graphit.py
# Out:
# eom chart20240608_184545.png

# %%
run graphit.py
# Out:
# eom chart20240608_184720.png

# %%
run graphit.py
# Out:
# eom chart20240608_185132.png

# %%
run graphit.py
# Out:
# eom chart20240608_185353.png

# %%
run graphit.py
# Out:
# eom chart20240608_185938.png

# %%
pdf.time.dtype
# Out:
# dtype('O')

# %%
pdf.time[0]
# Out:
# '2024-06-05 03:20:07'

# %%
pdf.time.to_datetime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2028725/2571174501.py in ?()
# ----> 1 pdf.time.to_datetime()
#
# ~/rtl433/venv/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_datetime'

# %%
run graphit.py
# Out:
# eom chart20240608_190410.png

# %%
run graphit.py
# Out:
# eom chart20240608_192023.png

# %%
run graphit.py
# Out:
# eom chart20240608_192254.png

# %%
run graphit.py
# Out:
# eom chart20240608_192347.png

# %%
run graphit.py
# Out:
# eom chart20240608_192444.png

# %%
run graphit.py
# Out:
# eom chart20240608_192835.png

# %%
sregy.dtype
# Out:
# dtype('float64')

# %%
sregy[0:100]
# Out:
# array([69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
#        69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
#        69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
#        69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
#        69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
#        69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
#        69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
#        69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
#        69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
#        69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
#        69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
#        69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
#        69930.75108845, 69930.75108845, 69930.75108845, 69930.75108845,
# ...

# %%
plt.plot(sregy)

# %%
run graphit.py
# Out:
# eom chart20240608_193241.png

# %%
run graphit.py
# Out:
# eom chart20240608_193503.png

# %%
run graph
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/rtl433/venv/lib/python3.10/site-packages/IPython/core/magics/execution.py:716, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     fpath = arg_lst[0]
# --> 716     filename = file_finder(fpath)
#     717 except IndexError as e:
#
# File ~/rtl433/venv/lib/python3.10/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'graph'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 get_ipython().run_line_magic('run', 'graph')
#
# ...

# %%
run graphit.py
# Out:
# eom chart20240608_193658.png

# %%
run graphit.py
# Out:
# eom chart20240608_193819.png

# %%
run graphit.py
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/rtl433/graphit.py:79
#      75 regdates = np.arange(datenums.min(),datenums.max(), 5*60)
#      77 regy = np.interp(regdates, datenums, comp)
# ---> 79 sregy = savgol_filter(regy, 3*60 )
#      81 # diff of consumption == consumption rate per regular spacing interval
#      82 regcr = np.diff(sregy)
#
# TypeError: savgol_filter() missing 1 required positional argument: 'polyorder'

# %%
run graphit.py
# Out:
# eom chart20240608_204249.png

# %%
run graphit.py
# Out:
# eom chart20240608_204837.png

# %%
run graphit.py
# Out:
# eom chart20240608_205026.png

# %%
run graphit.py
# Out:
# eom chart20240608_205229.png

# %%
    run graphit.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/rtl433/graphit.py:82
#      75 regdates = np.arange(datenums.min(),datenums.max(), 5*60)
#      77 regy = np.interp(regdates, datenums, comp)
# ---> 82 sregy = savgol_filter(regy, 60*60, 5, deriv=0, mode='interp' )
#      84 # diff of consumption == consumption rate per regular spacing interval
#      85 regcr = np.diff(sregy)
#
# File ~/rtl433/venv/lib/python3.10/site-packages/scipy/signal/_savitzky_golay.py:345, in savgol_filter(x, window_length, polyorder, deriv, delta, axis, mode, cval)
#     343 if mode == "interp":
#     344     if window_length > x.shape[axis]:
# --> 345         raise ValueError("If mode is 'interp', window_length must be less "
#     346                          "than or equal to the size of x.")
#     348     # Do not pad. Instead, for the elements within `window_length // 2`
# ...

# %%
regy.shape
# Out:
# (1135,)

# %%
1135/4/24
# Out:
# 11.822916666666666

# %%
from scipy.interpolate import CubicHermiteSpline

# %%
smooveb = yyy(regdates)

# %%
smooveb
# Out:
# array([69929., 69929., 69929., ..., 69973., 69973., 69973.])

# %%
plt.plot(np.diff(smooveb))

# %%
run graphit.py
# Out:
# eom chart20240608_212443.png

# %%
regdates
# Out:
# array([1.71755761e+09, 1.71755764e+09, 1.71755767e+09, ...,
#        1.71789979e+09, 1.71789982e+09, 1.71789985e+09])

# %%
np.diff(regdates)
# Out:
# array([30., 30., 30., ..., 30., 30., 30.])

# %%
yyy(regdates)
# Out:
# array([69929., 69929., 69929., ..., 69973., 69973., 69973.])

# %%
plt.plot(yyy(regdates))

# %%
run graphit.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/rtl433/graphit.py:81
#      77 yyy = CubicHermiteSpline(datenums,comp,comp*0)
#      79 regy = yyy(regdates)
# ---> 81 sregy = savgol_filter(regy, 5, 5, deriv=0, mode='interp' )
#      84 # diff of consumption == consumption rate per regular spacing interval
#      85 regcr = np.diff(sregy)
#
# File ~/rtl433/venv/lib/python3.10/site-packages/scipy/signal/_savitzky_golay.py:341, in savgol_filter(x, window_length, polyorder, deriv, delta, axis, mode, cval)
#     338 if x.dtype != np.float64 and x.dtype != np.float32:
#     339     x = x.astype(np.float64)
# --> 341 coeffs = savgol_coeffs(window_length, polyorder, deriv=deriv, delta=delta)
#     343 if mode == "interp":
#     344     if window_length > x.shape[axis]:
#
# ...

# %%
regy
# Out:
# array([69929., 69929., 69929., ..., 69973., 69973., 69973.])

# %%
run graphit.py
# Out:
# eom chart20240608_213355.png

# %%
run graphit.py
# Out:
# eom chart20240608_213536.png

# %%
run graphit.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/rtl433/graphit.py:104
#     101 ax[n].set_title('raw data: meter readings')
#     103 n += 1
# --> 104 ax[n].plot(regdatedates,regy,'-',label="regularized meter readings",lw=1)
#     105 ax[n].plot(regdatedates,sregy,'-',label='smoothed meter readings',lw=1)
#     106 ax[n].legend()
#
# NameError: name 'regy' is not defined

# %%
run graphit.py
# Out:
#   File ~/rtl433/graphit.py:104
#     //ax[n].plot(regdatedates,regy,'-',label="regularized meter readings",lw=1)
#     ^
# SyntaxError: invalid syntax

# %%
run graphit.py
# Out:
# eom chart20240608_214001.png

# %%
np.diff(comp)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
plt.hist(np.diff(comp))
# Out:
# (array([1.505e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 4.200e+01,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
atchange
# Out:
# (array([  49,   72,  106,  225,  295,  324,  326,  328,  329,  336,  350,
#          363,  365,  380,  452,  496,  501,  638,  660,  661,  697,  698,
#          712,  752,  848,  866,  873,  919,  986,  996, 1015, 1093, 1156,
#         1282, 1343, 1412, 1437, 1451, 1452, 1463, 1490, 1505, 1514]),)

# %%
list(comp)[atchange[0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 list(comp)[atchange[0]]
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
atchange[0]
# Out:
# array([  49,   72,  106,  225,  295,  324,  326,  328,  329,  336,  350,
#         363,  365,  380,  452,  496,  501,  638,  660,  661,  697,  698,
#         712,  752,  848,  866,  873,  919,  986,  996, 1015, 1093, 1156,
#        1282, 1343, 1412, 1437, 1451, 1452, 1463, 1490, 1505, 1514])

# %%
np.array(comp)[atchange[0]+1]
# Out:
# array([69930., 69931., 69932., 69933., 69934., 69935., 69936., 69937.,
#        69938., 69939., 69940., 69941., 69942., 69943., 69944., 69945.,
#        69946., 69947., 69948., 69949., 69950., 69951., 69952., 69953.,
#        69954., 69955., 69956., 69957., 69958., 69960., 69961., 69962.,
#        69963., 69964., 69965., 69966., 69967., 69968., 69969., 69970.,
#        69971., 69972., 69973.])

# %%
comp.shape
# Out:
# (1549,)

# %%
np.array(comp).shape
# Out:
# (1549,)

# %%
run graphit.py
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/rtl433/graphit.py:80
#      77 # the new value at the time of change is the closest to reality that we can possibly get.
#      79 acdates = datenums[atchange]
# ---> 80 accons  = comp[atchange]
#      81 fdhdg
#      84 # regular spaced dates 2/minute
#
# File ~/rtl433/venv/lib/python3.10/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     key = np.asarray(key, dtype=bool)
#    1005     return self._get_values(key)
# -> 1007 return self._get_with(key)
#
# File ~/rtl433/venv/lib/python3.10/site-packages/pandas/core/series.py:1042, in Series._get_with(self, key)
#    1038 if key_type == "integer":
#    1039     # We need to decide whether to treat this as a positional indexer
#    1040     #  (i.e. self.iloc) or label-based (i.e. self.loc)
# ...

# %%
run graphit.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/rtl433/graphit.py:81
#      79 acdates = datenums[atchange]
#      80 accons  = np.array(comp)[atchange]
# ---> 81 fdhdg
#      84 # regular spaced dates 2/minute
#      85 regdates_coarse = np.arange(datenums.min(),datenums.max(), 30*60)
#
# NameError: name 'fdhdg' is not defined

# %%
accons
# Out:
# array([69930., 69931., 69932., 69933., 69934., 69935., 69936., 69937.,
#        69938., 69939., 69940., 69941., 69942., 69943., 69944., 69945.,
#        69946., 69947., 69948., 69949., 69950., 69951., 69952., 69953.,
#        69954., 69955., 69956., 69957., 69958., 69960., 69961., 69962.,
#        69963., 69964., 69965., 69966., 69967., 69968., 69969., 69970.,
#        69971., 69972., 69973.])

# %%
acdates
# Out:
# array([1717570448, 1717580817, 1717589818, 1717613448, 1717627818,
#        1717632998, 1717633227, 1717634318, 1717634448, 1717635948,
#        1717638947, 1717643407, 1717643817, 1717648168, 1717665818,
#        1717675448, 1717677348, 1717710689, 1717713728, 1717714318,
#        1717721819, 1717722449, 1717725819, 1717737319, 1717758169,
#        1717762448, 1717764319, 1717773228, 1717786819, 1717789319,
#        1717793189, 1717809320, 1717820819, 1717849820, 1717859690,
#        1717872199, 1717879320, 1717881950, 1717882820, 1717885171,
#        1717892321, 1717894700, 1717896230], dtype=uint64)

# %%
plt.plot(acdates,accons,'.')

# %%
run graphit.py
# Out:
# eom chart20240608_221242.png

# %%
run graphit.pyru
# Out:
# eom chart20240608_222309.png

# %%
run graphit.py
# Out:
# eom chart20240608_222726.png
