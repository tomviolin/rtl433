# %%
run graphit.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/rtl433/graphit.py:75
#      72 #dates=dates[1:]
#      73 n=0
# ---> 75 ax[n].plot(regdatedates[:-1],regy,'.-',label="Consumption rate")
#      76 ax[n].legend()
#      77 #ax[n].set_xlim(xlim)
#
# File ~/rtl433/venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1668, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1425 """
#    1426 Plot y versus x as lines and/or markers.
#    1427
#    (...)
#    1665 (``'green'``) or hex strings (``'#008000'``).
#    1666 """
#    1667 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1668 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1669 for line in lines:
#    1670     self.add_line(line)
#
# File ~/rtl433/venv/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
# ...
